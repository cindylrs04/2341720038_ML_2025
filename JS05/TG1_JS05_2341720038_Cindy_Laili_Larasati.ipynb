# %% [markdown]
# <a href="https://colab.research.google.com/github/cindylrs04/2341720038_ML_2025/blob/main/JS05/TG1_JS05_2341720038_Cindy_Laili_Larasati.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAKTIKUM 1

# %% [markdown]
# Langkah 1 - Import Library

# %%
# Import required library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.decomposition import PCA

# %% [markdown]
# Langkah 2 - Load dan Inspeksi Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# Langkah 3 - Seleksi Fitur

# %%
# Features Selection
X = df.iloc[:, 1:-1] # slice the features
y = df.iloc[:, -1] # this is the labels (we don't need it)

# %%
print(X.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %% [markdown]
# Langkah 4 - Plotting

# %%
# Make a scatterplot using
# SepalLengthCm and SepalWidthCm
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], s = 100)

# %% [markdown]
# Langkah 5 - Membuat Model K-Means

# %%
# Build a K-Means Model
# Based on visual inspection using scatterplot,
# we can assumpt that the data has 2 cluster
# (even though, from the label, there are 3 labels in this data)

from sklearn.cluster import KMeans

# Initiate K-Means object with numbur of cluster is 2
cl_kmeans = KMeans(n_clusters=2)

# Fit and predict
y_kmeans = cl_kmeans.fit_predict(X)

# %%
# Plot the clustering result
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], s = 100, c=y_kmeans)

# Plot the centroid
centers = cl_kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)

# %% [markdown]
# Langkah 6 - Evaluasi Model

# %%
# Print SSE value
print(f'Nilai SSE: {cl_kmeans.inertia_}')
# Out:
# Nilai SSE: 152.36870647733915

# %% [markdown]
# Langkah 7 - Menentukan
# k
# k terbaik dengan Elbow Method

# %%
# Find the best k
# using Elbow Method

# List SSE values
sse = []

# Build k range from 1 to 9
K = range(1,10)

# Find the SSE value for each k
for k in K:
 kmeanModel = KMeans(n_clusters=k)
 kmeanModel.fit(X)
 sse.append(kmeanModel.inertia_)

# Plotting the distortions
plt.figure(figsize=(8,4))
plt.plot(K, sse, "bx-")
plt.xlabel("k")
plt.ylabel("SSE")
plt.title("Elbow Method to Find The Best K")
plt.show()

# %% [markdown]
# # PRAKTIKUM 2

# %% [markdown]
# Langkah 0 - Import Library

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Langkah 1 - Membuat Dataset Sintentis

# %%
from sklearn.datasets import make_moons

X, y = make_moons(200, noise=.05, random_state=0)

# %%
plt.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# Langkah 2 - Klasterisasi dengan K-Means

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(2, random_state=0)
cluster = kmeans.fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=cluster, s=50, cmap='viridis')

# %%
from sklearn.metrics import silhouette_score

print(silhouette_score(X, cluster))
# Out:
# 0.49215648268306905

# %% [markdown]
# Langkah 3 - Klasterisasi dengan DBSCAN

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.3, min_samples=2)
cluster_db = dbscan.fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=cluster_db, s=50, cmap='viridis')

# %%
from sklearn.metrics import silhouette_score

print(silhouette_score(X, cluster_db))

# Hasil 0.32585318950197517
# Out:
# 0.32585318950197517

# %%
from sklearn.metrics import davies_bouldin_score

# Compute and print Davies-Bouldin Index
db = davies_bouldin_score(X, cluster_db)

print(f"Davies-Bouldin Index: {db}")

# Hasilnya
# Davies-Bouldin Index: 1.1622685374061352
# Out:
# Davies-Bouldin Index: 1.1622685374061352

# %% [markdown]
# # PRAKTIKUM 3

# %% [markdown]
# Langkah 0 - Import Library

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Langkah 1 - Load Data Citra

# %%
from sklearn.datasets import load_sample_image
flower = load_sample_image("flower.jpg")
ax = plt.axes(xticks=[], yticks=[])
ax.imshow(flower)

# %% [markdown]
# Langkah 2 - Preprocessing

# %%
# Check shape
print(flower.shape)

# Normalize color
data = flower / 255.0

# Reshape
data = data.reshape(427 * 640, 3) # turn to 1D

print(data.shape)
# Out:
# (427, 640, 3)
# (273280, 3)

# %% [markdown]
# Langkah 3 - Cek Sebaran Warna

# %%
def plot_pixels(data, title, colors=None, N=10000):
    if colors is None:
        colors = data

    # choose a random subset
    rng = np.random.RandomState(0)
    i = rng.permutation(data.shape[0])[:N]
    colors = colors[i]
    R, G, B = data[i].T

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    ax[0].scatter(R, G, color=colors, marker='.')
    ax[0].set(xlabel='Red', ylabel='Green', xlim=(0, 1), ylim=(0, 1))

    ax[1].scatter(R, B, color=colors, marker='.')
    ax[1].set(xlabel='Red', ylabel='Blue', xlim=(0, 1), ylim=(0, 1))

    fig.suptitle(title, size=20);

# %%
plot_pixels(data, title='Input color space: 16 million possible colors')

# %% [markdown]
# Langkah 4 - Klasterisasi Warna

# %%
from sklearn.cluster import MiniBatchKMeans

kmeans = MiniBatchKMeans(16)
kmeans.fit(data)
new_colors = kmeans.cluster_centers_[kmeans.predict(data)]

plot_pixels(data, colors=new_colors,title="Reduced color space: 16 colors")

# %%
flower_recolored = new_colors.reshape(flower.shape)

fig, ax = plt.subplots(1, 2, figsize=(16, 6),
                       subplot_kw=dict(xticks=[], yticks=[]))
fig.subplots_adjust(wspace=0.05)
ax[0].imshow(flower)
ax[0].set_title('Original Image', size=16)
ax[1].imshow(flower_recolored)
ax[1].set_title('16-color Image', size=16);

# %% [markdown]
# # TUGAS PRAKTIKUM

# %% [markdown]
# 1. Buatlah scatterplot berdasarkan dataset menggunakan dua variabel, yaitu Avg_Credit_Limit dan Total_credit_card. Apakah sebaran data dapat dikatakan linier?

# %%
df = pd.read_csv('/content/drive/MyDrive/CC_Customer_Dataset.csv')
df.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Avg_Credit_Limit'], df['Total_Credit_Cards'], alpha=0.6)
plt.title('Scatter Plot: Avg_Credit_Limit vs Total_Credit_Cards')
plt.xlabel('Average Credit Limit')
plt.ylabel('Total Credit Cards')
plt.grid(True)
plt.show()

# %%
corr = df['Avg_Credit_Limit'].corr(df['Total_Credit_Cards'])
print(f"Koefisien korelasi Pearson: {corr:.3f}")
# Out:
# Koefisien korelasi Pearson: 0.609

# %%
if abs(corr) > 0.7:
    hubungan = "kuat"
elif abs(corr) > 0.4:
    hubungan = "sedang"
else:
    hubungan = "lemah"

print(f"Hubungan liniernya bersifat {hubungan}.")
# Out:
# Hubungan liniernya bersifat sedang.

# %% [markdown]
# 2. Buatlah model klasterisasi dengan menggunakan model K-Means. Tentukan jumlah
# k
# k yang terbaik dengan menggunakan elbow method. Lengkapi analisis Anda dengan linechart dan hasil analisis mengapa Anda memilih nilai tersebut.

# %%
X = df[['Avg_Credit_Limit', 'Total_Credit_Cards']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []
K = range(1, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,6))
plt.plot(K, wcss, 'o-', markersize=6)
plt.title('Elbow Method untuk Menentukan k Optimal')
plt.xlabel('Jumlah Cluster (k)')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.grid(True)
plt.show()

# %%
k_optimal = 3  # ubah sesuai titik siku grafik elbow kamu
kmeans_model = KMeans(n_clusters=k_optimal, random_state=42)
clusters = kmeans_model.fit_predict(X_scaled)

# %%
df['Cluster'] = clusters

# %%
print(df[['Avg_Credit_Limit','Total_Credit_Cards','Cluster']].head())
# Out:
#    Avg_Credit_Limit  Total_Credit_Cards  Cluster
# 0            100000                   2        2
# 1             50000                   3        2
# 2             50000                   7        0
# 3             30000                   5        0
# 4            100000                   6        0

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=clusters, cmap='viridis', alpha=0.6)
plt.title(f'Hasil Clustering K-Means (k={k_optimal})')
plt.xlabel('Avg_Credit_Limit (scaled)')
plt.ylabel('Total_Credit_Cards (scaled)')
plt.grid(True)
plt.show()

# %% [markdown]
# Grafik Elbow memperlihatkan bahwa penurunan WCSS cukup tajam hingga k=3, kemudian cenderung stabil. Oleh karena itu, jumlah cluster yang paling optimal dipilih k=3. Dengan tiga cluster tersebut, pelanggan dapat terkelompok dengan jelas berdasarkan kombinasi limit kredit dan jumlah kartu, sehingga memudahkan dalam menganalisis pola perilaku mereka.

# %% [markdown]
# 3. Gambarkan hasil klasterisasi dengan model K-Means dengan menggunakan scatterplot.

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=clusters, cmap='viridis', alpha=0.6)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
            s=200, c='red', marker='X', label='Centroid')
plt.title('Hasil Klasterisasi K-Means (k=3)')
plt.xlabel('Avg_Credit_Limit (scaled)')
plt.ylabel('Total_Credit_Cards (scaled)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 4. Buatlah model klasterisasi dengan menggunakan DBSCAN dengan seluruh variabel yang dapat digunakan.

# %%
X = df.drop(['Sl_No', 'Customer Key'], axis=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
dbscan = DBSCAN(eps=1.5, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

df['DBSCAN_Cluster'] = clusters

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    x=X_pca[:,0],
    y=X_pca[:,1],
    hue=clusters,
    palette='viridis',
    legend='full'
)
plt.title('Visualisasi DBSCAN dengan Seluruh Variabel (PCA 2D)')
plt.xlabel('Komponen Utama 1')
plt.ylabel('Komponen Utama 2')
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Tentukan jumlah
# k
# yang terbaik dengan menggunakan elbow method. Lengkapi analisis Anda dengan linechart dan hasil analisis mengapa Anda memilih nilai tersebut.

# %%
wcss = []
K = range(1,11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# 5. Plot linechart Elbow Method
plt.figure(figsize=(8,6))
plt.plot(K, wcss, 'o-', markersize=6)
plt.title('Elbow Method untuk Menentukan k Optimal')
plt.xlabel('Jumlah Cluster (k)')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.grid(True)
plt.show()

# %% [markdown]
# Hasil Elbow Method memperlihatkan penurunan WCSS yang signifikan hingga k=3, kemudian cenderung datar. Oleh karena itu, jumlah cluster optimal ditetapkan pada k=3. Dengan pembagian ini, data pelanggan tersegmentasi dengan jelas berdasarkan kombinasi variabel yang dianalisis, sehingga pola perilaku dapat dipelajari dengan lebih mudah.

# %% [markdown]
# 6. Tentukan nilai silhouette score dan DBI dari model DBSCAN.

# %%
dbscan = DBSCAN(eps=1.5, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

unique_labels = set(labels)
if len(unique_labels - {-1}) > 1:  # pastikan ada lebih dari 1 cluster sah
    sil_score = silhouette_score(X_scaled, labels)
    dbi_score = davies_bouldin_score(X_scaled, labels)
    print(f"Silhouette Score: {sil_score:.3f}")
    print(f"Davies-Bouldin Index (DBI): {dbi_score:.3f}")
else:
    print("Silhouette Score & DBI tidak dapat dihitung: hanya satu cluster atau semua outlier.")
# Out:
# Silhouette Score: 0.496
# Davies-Bouldin Index (DBI): 1.233
